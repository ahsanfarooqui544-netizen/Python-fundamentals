# %% [raw]
# Rule 1 No spaces dor declaring variables

# %%
father name = 'ritesh'
print(father name)
# Out:
#   Cell In[1], line 1
#     father name = 'ritesh'
#            ^
# SyntaxError: invalid syntax

# %%
fathername = 'Ritesh'
print(fathername)
# Out:
# Ritesh

# %%
1name = Mushtaq 
print(1name)
# Out:
#   Cell In[5], line 1
#     1name = Mushtaq
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Mushtaq"
print(name1)
# Out:
# Mushtaq

# %%
test# = 'naveed'
print(test#)
# Out:
#   Cell In[15], line 2
#     print(test#)
#                 ^
# _IncompleteInputError: incomplete input

# %%
Datatypes in Python
string - str
numbers - int for integers and float for decimals
list - list
tuples - tuple
dictionaries - dict

# %%
Applicantname = 'Steve smith'
print(Applicantname)
# Out:
# Steve smith

# %%
print(Applicantname.title())
# Out:
# Steve Smith

# %%
print(Applicantname.upper())
# Out:
# STEVE SMITH

# %%
print(Applicantname.lower())
# Out:
# steve smith

# %%
The Zen of python

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than right now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
# Out:
#   Cell In[8], line 10
#     Special cases aren't special enough to break the rules.
#                       ^
# SyntaxError: unterminated string literal (detected at line 10)

# %%
firstname = 'Irfan'
lastname = 'khan'
print(firstname)
print(lastname)
# Out:
# Irfan
# khan

# %%
fullname = f"{firstname}{lastname}"
#formula for joining two words or sentences we use 'f'
print(fullname)


message = f"Be ready for the party,{fullname.title()}"
print(message)
# Out:
# Irfankhan
# Be ready for the party,Irfankhan

# %%
print("Favourite _programming_languae:Python,Java,C++")
# Out:
# Favourite _programming_languae:Python,Java,C++

# %%
#Adding /n
print("Favourite _programming_languae:\nPython,\nJava,\nC++")
# Out:
# Favourite _programming_languae:
# Python,
# Java,
# C++

# %%
#Adding /tn
print("Favourite _programming_languae:\n\tPython,\n\tJava,\n\tC++")
# Out:
# Favourite _programming_languae:
# 	Python,
# 	Java,
# 	C++

# %%
#Removing whitespaces from strings
name = 'python'
print(name)
# Out:
# python

# %%
name2 = '   python'
print(name2)
# Out:
#    python

# %%
name3 = 'python   '
print(name3)
# Out:
# python

# %%
name4 = '        python       '
print(name4)
# Out:
#         python

# %%
num = 123
print(num)
type(num)
# Out:
# 123
# int

# %%
test = 0.1
print(test)
type(test)
# Out:
# 0.1
# float
